# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sms
import pandas as pd
from statsmodels.tsa.ar_model import AutoReg

# %matplotlib inline

# %%
df=pd.read_csv('user2_data.csv')
df.drop(['ttime','pm1','pm2','am','lum','temp','humd','pres'],axis=1,inplace=True)

#df.columns = df.columns[[0]].tolist() + list(range(1,2))
s = df.melt('sm')
s.head()
# Out:
#        sm variable  value
# 0  7463.0      pm3   0.00
# 1  7576.0      pm3   0.00
# 2  7576.0      pm3   0.00
# 3  7463.0      pm3   0.00
# 4  7463.0      pm3   2.51

# %%
s.isnull().sum()
# Out:
# sm          0
# variable    0
# value       0
# dtype: int64

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20166 entries, 0 to 20165
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sm        20166 non-null  float64
#  1   variable  20166 non-null  object
#  2   value     20166 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 472.8+ KB

# %%
s.plot()
# Out:
# <Axes: >

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def adf_test(series):
    result=adfuller(series)
    print('ADF Statistics: {}'.format(result[0]))
    print('p- value: {}'.format(result[1]))
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adf_test(s['value'])
# Out:
# ADF Statistics: -2.6007571323979657
# p- value: 0.09284088451858502
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
## Use Techniques Differencing
s['Moisture First Difference']=s['value']-s['value'].shift(1)

# %%
s.head()
# Out:
#        sm variable  value  Moisture First Difference
# 0  7463.0      pm3   0.00                        NaN
# 1  7576.0      pm3   0.00                       0.00
# 2  7576.0      pm3   0.00                       0.00
# 3  7463.0      pm3   0.00                       0.00
# 4  7463.0      pm3   2.51                       2.51

# %%
adf_test(s['Moisture First Difference'].dropna())
# Out:
# ADF Statistics: -9.07368533649762
# p- value: 4.2350676763739835e-15
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
## Use Techniques Differencing
s['Moisture Second Difference']=s['Moisture First Difference']-s['Moisture First Difference'].shift(1)

# %%
adf_test(s['Moisture Second Difference'].dropna())
# Out:
# ADF Statistics: -28.21558021819986
# p- value: 0.0
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
### 8 months 
## Use Techniques Differencing
s['Moisture 8 Difference']=s['value']-s['value'].shift(8)

# %%
adf_test(s['Moisture 8 Difference'].dropna())
# Out:
# ADF Statistics: -9.20548443052271
# p- value: 1.9501285966009887e-15
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
acf = plot_acf(s["Moisture Second Difference"].dropna())

# %%
acf12 = plot_acf(s["Moisture 8 Difference"].dropna())
pacf12 = plot_pacf(s["Moisture 8 Difference"].dropna())

# %%
result = plot_pacf(s["Moisture Second Difference"].dropna())

# %%
pacf12 = plot_pacf(s["Moisture 8 Difference"].dropna())

# %%
### split train and test data
s
# Out:
#            sm variable  value  Moisture First Difference  \
# 0      7463.0      pm3   0.00                        NaN
# 1      7576.0      pm3   0.00                       0.00
# 2      7576.0      pm3   0.00                       0.00
# 3      7463.0      pm3   0.00                       0.00
# 4      7463.0      pm3   2.51                       2.51
# ...       ...      ...    ...                        ...
# 20161   327.0      pm3  27.38                       0.00
# 20162   327.0      pm3  27.38                       0.00
# 20163   327.0      pm3  27.38                       0.00
# 20164   327.0      pm3  27.93                       0.55
# 20165   328.0      pm3  27.93                       0.00
#
#        Moisture Second Difference  Moisture 8 Difference
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                            0.00                    NaN
# 3                            0.00                    NaN
# 4                            2.51                    NaN
# ...                           ...                    ...
# 20161                        0.00                  -0.55
# 20162                        0.00                  -0.55
# 20163                        0.00                  -0.55
# 20164                        0.55                   0.00
# 20165                       -0.55                   0.00
#
# [20166 rows x 6 columns]

# %%
from datetime import datetime,timedelta
train_dataset_end=15124
test_dataset_end=20165

# %%
train_data=s[:train_dataset_end]
test_data=s[train_dataset_end:test_dataset_end]

# %%
##prediction
pred_start_date=test_data.index[0]
pred_end_date=test_data.index[-1]

# %%
test_data
# Out:
#           sm variable  value  Moisture First Difference  \
# 15124  469.0      pm3  37.43                       0.00
# 15125  469.0      pm3  37.43                       0.00
# 15126  468.0      pm3  37.43                       0.00
# 15127  468.0      pm3  37.43                       0.00
# 15128  468.0      pm3  37.43                       0.00
# ...      ...      ...    ...                        ...
# 20160  326.0      pm3  27.38                       0.00
# 20161  327.0      pm3  27.38                       0.00
# 20162  327.0      pm3  27.38                       0.00
# 20163  327.0      pm3  27.38                       0.00
# 20164  327.0      pm3  27.93                       0.55
#
#        Moisture Second Difference  Moisture 8 Difference
# 15124                        0.00                  -0.56
# 15125                        0.00                  -0.56
# 15126                        0.00                  -0.56
# 15127                        0.00                   0.00
# 15128                        0.00                   0.00
# ...                           ...                    ...
# 20160                        0.55                  -0.55
# 20161                        0.00                  -0.55
# 20162                        0.00                  -0.55
# 20163                        0.00                  -0.55
# 20164                        0.55                   0.00
#
# [5041 rows x 6 columns]

# %%
## create a ARIMA model
model_ARIMA = sms.tsa.arima.ARIMA(train_data['value'], order=(5,2,0))
model_Arima_fit = model_ARIMA.fit()
model_Arima_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                15124
# Model:                 ARIMA(5, 2, 0)   Log Likelihood               -4836.782
# Date:                Thu, 26 Dec 2024   AIC                           9685.564
# Time:                        21:02:37   BIC                           9731.308
# Sample:                             0   HQIC                          9700.735
#                               - 15124
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8113      0.003   -312.870      0.000      -0.816      -0.806
# ar.L2         -0.6260      0.003   -183.794      0.000      -0.633      -0.619
# ar.L3         -0.4694      0.004   -122.010      0.000      -0.477      -0.462
# ar.L4         -0.3222      0.004    -87.422      0.000      -0.329      -0.315
# ar.L5         -0.1567      0.003    -52.449      0.000      -0.163      -0.151
# sigma2         0.1110      0.000    954.593      0.000       0.111       0.111
# ===================================================================================
# Ljung-Box (L1) (Q):                  10.76   Jarque-Bera (JB):          36352182.27
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.16   Skew:                            11.49
# Prob(H) (two-sided):                  0.00   Kurtosis:                       242.09
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
train_data
# Out:
#            sm variable  value  Moisture First Difference  \
# 0      7463.0      pm3   0.00                        NaN
# 1      7576.0      pm3   0.00                       0.00
# 2      7576.0      pm3   0.00                       0.00
# 3      7463.0      pm3   0.00                       0.00
# 4      7463.0      pm3   2.51                       2.51
# ...       ...      ...    ...                        ...
# 15119   469.0      pm3  37.43                      -0.56
# 15120   469.0      pm3  37.43                       0.00
# 15121   469.0      pm3  37.43                       0.00
# 15122   469.0      pm3  37.43                       0.00
# 15123   469.0      pm3  37.43                       0.00
#
#        Moisture Second Difference  Moisture 8 Difference
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                            0.00                    NaN
# 3                            0.00                    NaN
# 4                            2.51                    NaN
# ...                           ...                    ...
# 15119                       -0.56                  -0.56
# 15120                        0.56                  -0.56
# 15121                        0.00                  -0.56
# 15122                        0.00                  -0.56
# 15123                        0.00                  -0.56
#
# [15124 rows x 6 columns]

# %%
model_ARIMA=sms.tsa.arima.ARIMA(train_data['value'],order=(0,2,23))

# %%
model_Arima_fit=model_ARIMA.fit()
# Out:
# c:\Users\acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model_Arima_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                15124
# Model:                ARIMA(0, 2, 23)   Log Likelihood                 403.652
# Date:                Thu, 26 Dec 2024   AIC                           -759.303
# Time:                        21:03:52   BIC                           -576.330
# Sample:                             0   HQIC                          -698.619
#                               - 15124
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -1.1945      0.003   -372.304      0.000      -1.201      -1.188
# ma.L2          0.1323      0.006     21.347      0.000       0.120       0.144
# ma.L3         -0.1189      0.008    -15.429      0.000      -0.134      -0.104
# ma.L4         -0.0551      0.007     -7.835      0.000      -0.069      -0.041
# ma.L5          0.1220      0.007     18.681      0.000       0.109       0.135
# ma.L6          0.1285      0.008     16.739      0.000       0.113       0.144
# ma.L7          0.0124      0.007      1.810      0.070      -0.001       0.026
# ma.L8          0.0682      0.005     13.132      0.000       0.058       0.078
# ma.L9         -0.0953      0.005    -19.079      0.000      -0.105      -0.085
# ma.L10        -0.0525      0.006     -8.841      0.000      -0.064      -0.041
# ma.L11         0.1467      0.006     24.401      0.000       0.135       0.159
# ma.L12         0.3483      0.003    101.552      0.000       0.342       0.355
# ma.L13        -0.4951      0.005   -104.653      0.000      -0.504      -0.486
# ma.L14         0.1739      0.005     32.376      0.000       0.163       0.184
# ma.L15        -0.1326      0.006    -21.249      0.000      -0.145      -0.120
# ma.L16        -0.2100      0.006    -34.717      0.000      -0.222      -0.198
# ma.L17         0.1714      0.006     30.381      0.000       0.160       0.182
# ma.L18        -0.0479      0.007     -7.279      0.000      -0.061      -0.035
# ma.L19         0.2262      0.006     37.092      0.000       0.214       0.238
# ma.L20         0.1572      0.005     28.693      0.000       0.146       0.168
# ma.L21        -0.2928      0.005    -54.425      0.000      -0.303      -0.282
# ma.L22        -0.0765      0.007    -10.788      0.000      -0.090      -0.063
# ma.L23         0.1129      0.005     24.564      0.000       0.104       0.122
# sigma2         0.0554      0.000    351.296      0.000       0.055       0.056
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):           5693531.21
# Prob(Q):                              0.86   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.26   Skew:                             4.55
# Prob(H) (two-sided):                  0.00   Kurtosis:                        97.62
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
test_data
# Out:
#           sm variable  value  Moisture First Difference  \
# 15124  469.0      pm3  37.43                       0.00
# 15125  469.0      pm3  37.43                       0.00
# 15126  468.0      pm3  37.43                       0.00
# 15127  468.0      pm3  37.43                       0.00
# 15128  468.0      pm3  37.43                       0.00
# ...      ...      ...    ...                        ...
# 20160  326.0      pm3  27.38                       0.00
# 20161  327.0      pm3  27.38                       0.00
# 20162  327.0      pm3  27.38                       0.00
# 20163  327.0      pm3  27.38                       0.00
# 20164  327.0      pm3  27.93                       0.55
#
#        Moisture Second Difference  Moisture 8 Difference
# 15124                        0.00                  -0.56
# 15125                        0.00                  -0.56
# 15126                        0.00                  -0.56
# 15127                        0.00                   0.00
# 15128                        0.00                   0.00
# ...                           ...                    ...
# 20160                        0.55                  -0.55
# 20161                        0.00                  -0.55
# 20162                        0.00                  -0.55
# 20163                        0.00                  -0.55
# 20164                        0.55                   0.00
#
# [5041 rows x 6 columns]

# %%
pred=model_Arima_fit.predict(start=pred_start_date,end=pred_end_date)
residuals=test_data['value']-pred

# %%
pred
# Out:
# 15124     37.484285
# 15125     37.564775
# 15126     37.619121
# 15127     37.564508
# 15128     37.551099
#             ...
# 20160   -123.249469
# 20161   -123.281404
# 20162   -123.313339
# 20163   -123.345274
# 20164   -123.377209
# Name: predicted_mean, Length: 5041, dtype: float64

# %%
residuals
# Out:
# 15124     -0.054285
# 15125     -0.134775
# 15126     -0.189121
# 15127     -0.134508
# 15128     -0.121099
#             ...
# 20160    150.629469
# 20161    150.661404
# 20162    150.693339
# 20163    150.725274
# 20164    151.307209
# Length: 5041, dtype: float64

# %%
model_Arima_fit.resid.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
test_data['Predicted_ARIMA']=pred
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_17644\95659616.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['Predicted_ARIMA']=pred

# %%
test_data[['value','Predicted_ARIMA']].plot()
# Out:
# <Axes: >

# %%
acf8 = plot_acf(s["Moisture 8 Difference"].dropna())
pacf8 = plot_pacf(s["Moisture 8 Difference"].dropna())

# %%
## create a SARIMA model
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model_SARIMA=SARIMAX(train_data['value'],order=(1,0,3),seasonal_order=(1,1,1,12))

# %%
model_SARIMA_fit=model_SARIMA.fit()

# %%
model_SARIMA_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                value   No. Observations:                15124
# Model:             SARIMAX(1, 0, 3)x(1, 1, [1], 12)   Log Likelihood                1555.346
# Date:                              Thu, 26 Dec 2024   AIC                          -3096.693
# Time:                                      21:04:29   BIC                          -3043.330
# Sample:                                           0   HQIC                         -3078.994
#                                             - 15124
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9993      0.000   7133.890      0.000       0.999       1.000
# ma.L1         -0.1848      0.002   -108.167      0.000      -0.188      -0.181
# ma.L2         -0.0583      0.005    -11.071      0.000      -0.069      -0.048
# ma.L3         -0.1445      0.005    -31.802      0.000      -0.153      -0.136
# ar.S.L12       0.0650      0.003     25.431      0.000       0.060       0.070
# ma.S.L12      -0.6564      0.002   -348.454      0.000      -0.660      -0.653
# sigma2         0.0476   9.17e-05    518.991      0.000       0.047       0.048
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.66   Jarque-Bera (JB):          15484545.75
# Prob(Q):                              0.06   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.56   Skew:                            -0.46
# Prob(H) (two-sided):                  0.00   Kurtosis:                       159.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
test_data.tail()
# Out:
#           sm variable  value  Moisture First Difference  \
# 20160  326.0      pm3  27.38                       0.00
# 20161  327.0      pm3  27.38                       0.00
# 20162  327.0      pm3  27.38                       0.00
# 20163  327.0      pm3  27.38                       0.00
# 20164  327.0      pm3  27.93                       0.55
#
#        Moisture Second Difference  Moisture 8 Difference  Predicted_ARIMA
# 20160                        0.55                  -0.55      -123.249469
# 20161                        0.00                  -0.55      -123.281404
# 20162                        0.00                  -0.55      -123.313339
# 20163                        0.00                  -0.55      -123.345274
# 20164                        0.55                   0.00      -123.377209

# %%
pred_Sarima=model_SARIMA_fit.predict(start=15125,end=20164)
residuals=test_data['value']-pred_Sarima

# %%
model_SARIMA_fit.resid.plot()
# Out:
# <Axes: >

# %%
model_SARIMA_fit.resid.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
test_data['Predicted_SARIMA']=pred_Sarima
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_17644\1367177785.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['Predicted_SARIMA']=pred_Sarima

# %%
test_data
# Out:
#           sm variable  value  Moisture First Difference  \
# 15124  469.0      pm3  37.43                       0.00
# 15125  469.0      pm3  37.43                       0.00
# 15126  468.0      pm3  37.43                       0.00
# 15127  468.0      pm3  37.43                       0.00
# 15128  468.0      pm3  37.43                       0.00
# ...      ...      ...    ...                        ...
# 20160  326.0      pm3  27.38                       0.00
# 20161  327.0      pm3  27.38                       0.00
# 20162  327.0      pm3  27.38                       0.00
# 20163  327.0      pm3  27.38                       0.00
# 20164  327.0      pm3  27.93                       0.55
#
#        Moisture Second Difference  Moisture 8 Difference  Predicted_ARIMA  \
# 15124                        0.00                  -0.56        37.484285
# 15125                        0.00                  -0.56        37.564775
# 15126                        0.00                  -0.56        37.619121
# 15127                        0.00                   0.00        37.564508
# 15128                        0.00                   0.00        37.551099
# ...                           ...                    ...              ...
# 20160                        0.55                  -0.55      -123.249469
# 20161                        0.00                  -0.55      -123.281404
# 20162                        0.00                  -0.55      -123.313339
# 20163                        0.00                  -0.55      -123.345274
# 20164                        0.55                   0.00      -123.377209
#
#        Predicted_SARIMA
# 15124               NaN
# 15125         37.439375
# 15126         37.428738
# 15127         37.429299
# 15128         37.429860
# ...                 ...
# 20160          5.801760
# 20161          5.824978
# 20162          5.848179
# 20163          5.791477
# 20164          5.814405
#
# [5041 rows x 8 columns]

# %%
test_data[['value','Predicted_SARIMA','Predicted_ARIMA']].plot()
# Out:
# <Axes: >

# %%
model2 = SARIMAX(train_data['value'],order=(1,0,3),seasonal_order=(1,1,1,8))
result2 = model2.fit()
s.tail()
future_pred=pd.date_range(start='2022-07-18',end='2023-03-31')
pred2=result2.predict(start=len(s),end=len(s)+35,typ='levels')
# Out:
# c:\Users\acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# c:\Users\acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning: Unknown keyword arguments: dict_keys(['typ']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
#   warnings.warn(msg, FutureWarning)

# %%
pred2.to_csv('pred.csv')
pred2
# Out:
# 20166   -29.431473
# 20167   -29.495542
# 20168   -29.492196
# 20169   -29.488850
# 20170   -29.485503
# 20171   -29.535958
# 20172   -29.531856
# 20173   -29.527418
# 20174   -29.525060
# 20175   -29.589125
# 20176   -29.585774
# 20177   -29.582423
# 20178   -29.579072
# 20179   -29.629522
# 20180   -29.625415
# 20181   -29.620972
# 20182   -29.618610
# 20183   -29.682670
# 20184   -29.679314
# 20185   -29.675959
# 20186   -29.672603
# 20187   -29.723049
# 20188   -29.718938
# 20189   -29.714490
# 20190   -29.712123
# 20191   -29.776178
# 20192   -29.772818
# 20193   -29.769458
# 20194   -29.766098
# 20195   -29.816538
# 20196   -29.812423
# 20197   -29.807970
# 20198   -29.805599
# 20199   -29.869650
# 20200   -29.866285
# 20201   -29.862920
# Name: predicted_mean, dtype: float64

# %%
# test_data['SARIMA_pred']=pred2
plt.rcParams['figure.figsize'] = [8, 5]
plt.title("Amount of soil moisture from June 2022 - march 2023")
plt.plot(test_data[['value','Predicted_SARIMA','Predicted_ARIMA']])
# Out:
# [<matplotlib.lines.Line2D at 0x1deb2661e20>,
#  <matplotlib.lines.Line2D at 0x1deb665b080>,
#  <matplotlib.lines.Line2D at 0x1deb66c20c0>]
